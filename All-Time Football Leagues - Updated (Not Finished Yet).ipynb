# %%
# !pip install requests beautifulsoup4 pandas

import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
# Step 1: Fetch the HTML content of the webpage
url1 = 'https://www.worldfootball.net/alltime_table/eng-premier-league/'
response = requests.get(url1)

# Check if the request was successful
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Step 2: Locate the table in the HTML
    table1 = soup.find('table', {'class': 'standard_tabelle'})
    
    # Step 3: Extract headers
    headers1 = [th.text.strip() for th in table1.find_all('th')]
    print(f"Headers (Columns): {headers1}")
    print(f"Number of Columns in Headers: {len(headers1)}")
    
    # Step 4: Extract table rows
    rows = []
    for tr in table1.find_all('tr')[1:]:  # Skip header row
        cols = [td.text.strip() for td in tr.find_all('td')]
        if cols:  # Skip empty rows
            rows.append(cols)
    
    print(f"First Row: {rows[0]}")
    print(f"Number of Columns in First Row: {len(rows[0])}")

    # Step 5: Ensure Column Alignment
    if len(headers1) < len(rows[0]):
        # Add placeholder headers for extra columns
        headers1 += [f"Extra Column {i+1}" for i in range(len(rows[0]) - len(headers1))]
    elif len(headers1) > len(rows[0]):
        print("Warning: Headers have more columns than data rows.")
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")

df_eng = pd.DataFrame(rows, columns = headers1)
# Out:
# Headers (Columns): ['#', 'Team', 'M.', 'W', 'D', 'L', 'goals', 'Dif', 'Pt.']
# Number of Columns in Headers: 9
# First Row: ['1', '', 'Liverpool FC', '4353', '2080', '1078', '1195', '7345:5218', '2127', '7318']
# Number of Columns in First Row: 10

# %%
# df_eng.head(5)

# %%
# Step 1: Fetch the HTML content of the webpage
url2 = 'https://www.worldfootball.net/alltime_table/ita-serie-a/'
response = requests.get(url2)

# Check if the request was successful
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Step 2: Locate the table in the HTML
    table2 = soup.find('table', {'class': 'standard_tabelle'})
    
    # Step 3: Extract headers
    headers2 = [th.text.strip() for th in table2.find_all('th')]
    print(f"Headers (Columns): {headers2}")
    print(f"Number of Columns in Headers: {len(headers2)}")
    
    # Step 4: Extract table rows
    rows = []
    for tr in table2.find_all('tr')[1:]:  # Skip header row
        cols = [td.text.strip() for td in tr.find_all('td')]
        if cols:  # Skip empty rows
            rows.append(cols)
    
    print(f"First Row: {rows[0]}")
    print(f"Number of Columns in First Row: {len(rows[0])}")

    # Step 5: Ensure Column Alignment
    if len(headers2) < len(rows[0]):
        # Add placeholder headers for extra columns
        headers2 += [f"Extra Column {i+1}" for i in range(len(rows[0]) - len(headers2))]
    elif len(headers2) > len(rows[0]):
        print("Warning: Headers have more columns than data rows.")
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")

df_ita = pd.DataFrame(rows, columns = headers2)
# Out:
# Headers (Columns): ['#', 'Team', 'M.', 'W', 'D', 'L', 'goals', 'Dif', 'Pt.']
# Number of Columns in Headers: 9
# First Row: ['1', '', 'Juventus', '3147', '1728', '857', '562', '5486:2963', '2523', '6031']
# Number of Columns in First Row: 10

# %%
# df_ita.head(6)

# %%
# Step 1: Fetch the HTML content of the webpage
url3 = 'https://www.worldfootball.net/alltime_table/esp-primera-division/'
response = requests.get(url3)

# Check if the request was successful
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Step 2: Locate the table in the HTML
    table3 = soup.find('table', {'class': 'standard_tabelle'})
    
    # Step 3: Extract headers
    headers3 = [th.text.strip() for th in table3.find_all('th')]
    print(f"Headers (Columns): {headers3}")
    print(f"Number of Columns in Headers: {len(headers3)}")
    
    # Step 4: Extract table rows
    rows = []
    for tr in table3.find_all('tr')[1:]:  # Skip header row
        cols = [td.text.strip() for td in tr.find_all('td')]
        if cols:  # Skip empty rows
            rows.append(cols)
    
    print(f"First Row: {rows[0]}")
    print(f"Number of Columns in First Row: {len(rows[0])}")

    # Step 5: Ensure Column Alignment
    if len(headers3) < len(rows[0]):
        # Add placeholder headers for extra columns
        headers3 += [f"Extra Column {i+1}" for i in range(len(rows[0]) - len(headers3))]
    elif len(headers3) > len(rows[0]):
        print("Warning: Headers have more columns than data rows.")
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")

df_esp = pd.DataFrame(rows, columns = headers3)
# Out:
# Headers (Columns): ['#', 'Team', 'M.', 'W', 'D', 'L', 'goals', 'Dif', 'Pt.']
# Number of Columns in Headers: 9
# First Row: ['1', '', 'Real Madrid', '3056', '1838', '613', '605', '6542:3403', '3139', '6127']
# Number of Columns in First Row: 10

# %%
# df_esp.head(6)

# %%
# Step 1: Fetch the HTML content of the webpage
url4 = 'https://www.worldfootball.net/alltime_table/bundesliga/'
response = requests.get(url4)

# Check if the request was successful
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Step 2: Locate the table in the HTML
    table4 = soup.find('table', {'class': 'standard_tabelle'})
    
    # Step 3: Extract headers
    headers4 = [th.text.strip() for th in table4.find_all('th')]
    print(f"Headers (Columns): {headers4}")
    print(f"Number of Columns in Headers: {len(headers4)}")
    
    # Step 4: Extract table rows
    rows = []
    for tr in table4.find_all('tr')[1:]:  # Skip header row
        cols = [td.text.strip() for td in tr.find_all('td')]
        if cols:  # Skip empty rows
            rows.append(cols)
    
    print(f"First Row: {rows[0]}")
    print(f"Number of Columns in First Row: {len(rows[0])}")

    # Step 5: Ensure Column Alignment
    if len(headers4) < len(rows[0]):
        # Add placeholder headers for extra columns
        headers4 += [f"Extra Column {i+1}" for i in range(len(rows[0]) - len(headers4))]
    elif len(headers4) > len(rows[0]):
        print("Warning: Headers have more columns than data rows.")
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")

df_ger = pd.DataFrame(rows, columns = headers4)
# Out:
# Headers (Columns): ['#', 'Team', 'M.', 'W', 'D', 'L', 'goals', 'Dif', 'Pt.']
# Number of Columns in Headers: 9
# First Row: ['1', '', 'Bayern München', '2036', '1231', '436', '369', '4590:2221', '2369', '4129']
# Number of Columns in First Row: 10

# %%
# df_ger.head(7)

# %%
# Step 1: Fetch the HTML content of the webpage
url5 = 'https://www.worldfootball.net/alltime_table/por-primeira-liga/'
response = requests.get(url5)

# Check if the request was successful
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Step 2: Locate the table in the HTML
    table5 = soup.find('table', {'class': 'standard_tabelle'})
    
    # Step 3: Extract headers
    headers5 = [th.text.strip() for th in table5.find_all('th')]
    print(f"Headers (Columns): {headers5}")
    print(f"Number of Columns in Headers: {len(headers5)}")
    
    # Step 4: Extract table rows
    rows = []
    for tr in table5.find_all('tr')[1:]:  # Skip header row
        cols = [td.text.strip() for td in tr.find_all('td')]
        if cols:  # Skip empty rows
            rows.append(cols)
    
    print(f"First Row: {rows[0]}")
    print(f"Number of Columns in First Row: {len(rows[0])}")

    # Step 5: Ensure Column Alignment
    if len(headers5) < len(rows[0]):
        # Add placeholder headers for extra columns
        headers5 += [f"Extra Column {i+1}" for i in range(len(rows[0]) - len(headers5))]
    elif len(headers5) > len(rows[0]):
        print("Warning: Headers have more columns than data rows.")
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")

df_por = pd.DataFrame(rows, columns = headers5)
# Out:
# Headers (Columns): ['#', 'Team', 'M.', 'W', 'D', 'L', 'goals', 'Dif', 'Pt.']
# Number of Columns in Headers: 9
# First Row: ['1', '', 'SL Benfica', '2159', '1485', '417', '257', '4869:1635', '3234', '4872']
# Number of Columns in First Row: 10

# %%
# df_por.head(6)

# %%
# Step 1: Fetch the HTML content of the webpage
url6 = 'https://www.worldfootball.net/alltime_table/fra-ligue-1/'
response = requests.get(url6)

# Check if the request was successful
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Step 2: Locate the table in the HTML
    table6 = soup.find('table', {'class': 'standard_tabelle'})
    
    # Step 3: Extract headers
    headers6 = [th.text.strip() for th in table6.find_all('th')]
    print(f"Headers (Columns): {headers6}")
    print(f"Number of Columns in Headers: {len(headers6)}")
    
    # Step 4: Extract table rows
    rows = []
    for tr in table6.find_all('tr')[1:]:  # Skip header row
        cols = [td.text.strip() for td in tr.find_all('td')]
        if cols:  # Skip empty rows
            rows.append(cols)
    
    print(f"First Row: {rows[0]}")
    print(f"Number of Columns in First Row: {len(rows[0])}")

    # Step 5: Ensure Column Alignment
    if len(headers6) < len(rows[0]):
        # Add placeholder headers for extra columns
        headers6 += [f"Extra Column {i+1}" for i in range(len(rows[0]) - len(headers6))]
    elif len(headers6) > len(rows[0]):
        print("Warning: Headers have more columns than data rows.")
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")

df_fra = pd.DataFrame(rows, columns = headers6)
# Out:
# Headers (Columns): ['#', 'Team', 'M.', 'W', 'D', 'L', 'goals', 'Dif', 'Pt.']
# Number of Columns in Headers: 9
# First Row: ['1', '', 'Olympique Marseille', '2676', '1199', '682', '795', '4315:3416', '899', '4278']
# Number of Columns in First Row: 10

# %%
# df_fra.head(5)

# %%
df_eng.drop(columns=["Team"], inplace=True)
df_eng.columns = [["All-Time Domestic Position", "Team", "Matches", "Win", "Draw", "Loss", "GS:GC", "GD", "Total Points"]]

df_ita.drop(columns=["Team"], inplace=True)
df_ita.columns = [["All-Time Domestic Position", "Team", "Matches", "Win", "Draw", "Loss", "GS:GC", "GD", "Total Points"]]

df_esp.drop(columns=["Team"], inplace=True)
df_esp.columns = [["All-Time Domestic Position", "Team", "Matches", "Win", "Draw", "Loss", "GS:GC", "GD", "Total Points"]]

df_ger.drop(columns=["Team"], inplace=True)
df_ger.columns = [["All-Time Domestic Position", "Team", "Matches", "Win", "Draw", "Loss", "GS:GC", "GD", "Total Points"]]

df_por.drop(columns=["Team"], inplace=True)
df_por.columns = [["All-Time Domestic Position", "Team", "Matches", "Win", "Draw", "Loss", "GS:GC", "GD", "Total Points"]]

df_fra.drop(columns=["Team"], inplace=True)
df_fra.columns = [["All-Time Domestic Position", "Team", "Matches", "Win", "Draw", "Loss", "GS:GC", "GD", "Total Points"]]

# %%
df_eng[["Matches", "Win", "Draw", "Loss", "GD", "Total Points"]] = df_eng[["Matches", "Win", "Draw", "Loss", "GD", "Total Points"]].astype(float)
df_ita[["Matches", "Win", "Draw", "Loss", "GD", "Total Points"]] = df_ita[["Matches", "Win", "Draw", "Loss", "GD", "Total Points"]].astype(float)
df_esp[["Matches", "Win", "Draw", "Loss", "GD", "Total Points"]] = df_esp[["Matches", "Win", "Draw", "Loss", "GD", "Total Points"]].astype(float)
df_ger[["Matches", "Win", "Draw", "Loss", "GD", "Total Points"]] = df_ger[["Matches", "Win", "Draw", "Loss", "GD", "Total Points"]].astype(float)
df_por[["Matches", "Win", "Draw", "Loss", "GD", "Total Points"]] = df_por[["Matches", "Win", "Draw", "Loss", "GD", "Total Points"]].astype(float)
df_fra[["Matches", "Win", "Draw", "Loss", "GD", "Total Points"]] = df_fra[["Matches", "Win", "Draw", "Loss", "GD", "Total Points"]].astype(float)

# %%
# Extracting Effective Columns from the GS:GC Column
df_eng[["Goals Scored", "Goals Conceded"]] = df_eng["GS:GC"].iloc[:, 0].str.split(":", expand=True)
df_ita[["Goals Scored", "Goals Conceded"]] = df_ita["GS:GC"].iloc[:, 0].str.split(":", expand=True)
df_esp[["Goals Scored", "Goals Conceded"]] = df_esp["GS:GC"].iloc[:, 0].str.split(":", expand=True)
df_ger[["Goals Scored", "Goals Conceded"]] = df_ger["GS:GC"].iloc[:, 0].str.split(":", expand=True)
df_por[["Goals Scored", "Goals Conceded"]] = df_por["GS:GC"].iloc[:, 0].str.split(":", expand=True)
df_fra[["Goals Scored", "Goals Conceded"]] = df_fra["GS:GC"].iloc[:, 0].str.split(":", expand=True)

# Converting the New Columns to Appropriate Numeric Data Types
df_eng[["Goals Scored", "Goals Conceded"]] = df_eng[["Goals Scored", "Goals Conceded"]].astype(float)
df_ita[["Goals Scored", "Goals Conceded"]] = df_ita[["Goals Scored", "Goals Conceded"]].astype(float)
df_esp[["Goals Scored", "Goals Conceded"]] = df_esp[["Goals Scored", "Goals Conceded"]].astype(float)
df_ger[["Goals Scored", "Goals Conceded"]] = df_ger[["Goals Scored", "Goals Conceded"]].astype(float)
df_por[["Goals Scored", "Goals Conceded"]] = df_por[["Goals Scored", "Goals Conceded"]].astype(float)
df_fra[["Goals Scored", "Goals Conceded"]] = df_fra[["Goals Scored", "Goals Conceded"]].astype(float)

# %%
# df_eng.dtypes

# %%
# Points per Game
df_eng["PPG"] = (df_eng["Total Points"].iloc[:, 0]/df_eng["Matches"].iloc[:, 0]).round(3)
df_ita["PPG"] = (df_ita["Total Points"].iloc[:, 0]/df_ita["Matches"].iloc[:, 0]).round(3)
df_esp["PPG"] = (df_esp["Total Points"].iloc[:, 0]/df_esp["Matches"].iloc[:, 0]).round(3)
df_ger["PPG"] = (df_ger["Total Points"].iloc[:, 0]/df_ger["Matches"].iloc[:, 0]).round(3)
df_por["PPG"] = (df_por["Total Points"].iloc[:, 0]/df_por["Matches"].iloc[:, 0]).round(3)
df_fra["PPG"] = (df_fra["Total Points"].iloc[:, 0]/df_fra["Matches"].iloc[:, 0]).round(3)

# Wins per Game
df_eng["WPG"] = (df_eng["Win"].iloc[:, 0]/df_eng["Matches"].iloc[:, 0]).round(3)
df_ita["WPG"] = (df_ita["Win"].iloc[:, 0]/df_ita["Matches"].iloc[:, 0]).round(3)
df_esp["WPG"] = (df_esp["Win"].iloc[:, 0]/df_esp["Matches"].iloc[:, 0]).round(3)
df_ger["WPG"] = (df_ger["Win"].iloc[:, 0]/df_ger["Matches"].iloc[:, 0]).round(3)
df_por["WPG"] = (df_por["Win"].iloc[:, 0]/df_por["Matches"].iloc[:, 0]).round(3)
df_fra["WPG"] = (df_fra["Win"].iloc[:, 0]/df_fra["Matches"].iloc[:, 0]).round(3)

# Draws per Game
df_eng["DPG"] = (df_eng["Draw"].iloc[:, 0]/df_eng["Matches"].iloc[:, 0]).round(3)
df_ita["DPG"] = (df_ita["Draw"].iloc[:, 0]/df_ita["Matches"].iloc[:, 0]).round(3)
df_esp["DPG"] = (df_esp["Draw"].iloc[:, 0]/df_esp["Matches"].iloc[:, 0]).round(3)
df_ger["DPG"] = (df_ger["Draw"].iloc[:, 0]/df_ger["Matches"].iloc[:, 0]).round(3)
df_por["DPG"] = (df_por["Draw"].iloc[:, 0]/df_por["Matches"].iloc[:, 0]).round(3)
df_fra["DPG"] = (df_fra["Draw"].iloc[:, 0]/df_fra["Matches"].iloc[:, 0]).round(3)

# Losses per Game
df_eng["LPG"] = (df_eng["Loss"].iloc[:, 0]/df_eng["Matches"].iloc[:, 0]).round(3)
df_ita["LPG"] = (df_ita["Loss"].iloc[:, 0]/df_ita["Matches"].iloc[:, 0]).round(3)
df_esp["LPG"] = (df_esp["Loss"].iloc[:, 0]/df_esp["Matches"].iloc[:, 0]).round(3)
df_ger["LPG"] = (df_ger["Loss"].iloc[:, 0]/df_ger["Matches"].iloc[:, 0]).round(3)
df_por["LPG"] = (df_por["Loss"].iloc[:, 0]/df_por["Matches"].iloc[:, 0]).round(3)
df_fra["LPG"] = (df_fra["Loss"].iloc[:, 0]/df_fra["Matches"].iloc[:, 0]).round(3)

# Average Goals Scored per Game
df_eng["GSPG"] = (df_eng["Goals Scored"].iloc[:, 0]/df_eng["Matches"].iloc[:, 0]).round(3)
df_ita["GSPG"] = (df_ita["Goals Scored"].iloc[:, 0]/df_ita["Matches"].iloc[:, 0]).round(3)
df_esp["GSPG"] = (df_esp["Goals Scored"].iloc[:, 0]/df_esp["Matches"].iloc[:, 0]).round(3)
df_ger["GSPG"] = (df_ger["Goals Scored"].iloc[:, 0]/df_ger["Matches"].iloc[:, 0]).round(3)
df_por["GSPG"] = (df_por["Goals Scored"].iloc[:, 0]/df_por["Matches"].iloc[:, 0]).round(3)
df_fra["GSPG"] = (df_fra["Goals Scored"].iloc[:, 0]/df_fra["Matches"].iloc[:, 0]).round(3)

# Average Goals Conceded per Game
df_eng["GCPG"] = (df_eng["Goals Conceded"].iloc[:, 0]/df_eng["Matches"].iloc[:, 0]).round(3)
df_ita["GCPG"] = (df_ita["Goals Conceded"].iloc[:, 0]/df_ita["Matches"].iloc[:, 0]).round(3)
df_esp["GCPG"] = (df_esp["Goals Conceded"].iloc[:, 0]/df_esp["Matches"].iloc[:, 0]).round(3)
df_ger["GCPG"] = (df_ger["Goals Conceded"].iloc[:, 0]/df_ger["Matches"].iloc[:, 0]).round(3)
df_por["GCPG"] = (df_por["Goals Conceded"].iloc[:, 0]/df_por["Matches"].iloc[:, 0]).round(3)
df_fra["GCPG"] = (df_fra["Goals Conceded"].iloc[:, 0]/df_fra["Matches"].iloc[:, 0]).round(3)

# %%
# Flatten the multi-index column names
df_eng.columns = [' '.join(col).strip() if isinstance(col, tuple) else col for col in df_eng.columns]
df_ita.columns = [' '.join(col).strip() if isinstance(col, tuple) else col for col in df_ita.columns]
df_esp.columns = [' '.join(col).strip() if isinstance(col, tuple) else col for col in df_esp.columns]
df_ger.columns = [' '.join(col).strip() if isinstance(col, tuple) else col for col in df_ger.columns]
df_por.columns = [' '.join(col).strip() if isinstance(col, tuple) else col for col in df_por.columns]
df_fra.columns = [' '.join(col).strip() if isinstance(col, tuple) else col for col in df_fra.columns]

# %%
# Each Nation's Average All-Time GSPG
df_eng["Country GSPG"] = df_eng["GSPG"].mean().round(3)
df_ita["Country GSPG"] = df_ita["GSPG"].mean().round(3)
df_esp["Country GSPG"] = df_esp["GSPG"].mean().round(3)
df_ger["Country GSPG"] = df_ger["GSPG"].mean().round(3)
df_por["Country GSPG"] = df_por["GSPG"].mean().round(3)
df_fra["Country GSPG"] = df_fra["GSPG"].mean().round(3)

# Each Nation's Average All-Time GCPG
df_eng["Country GCPG"] = df_eng["GCPG"].mean().round(3)
df_ita["Country GCPG"] = df_ita["GCPG"].mean().round(3)
df_esp["Country GCPG"] = df_esp["GCPG"].mean().round(3)
df_ger["Country GCPG"] = df_ger["GCPG"].mean().round(3)
df_por["Country GCPG"] = df_por["GCPG"].mean().round(3)
df_fra["Country GCPG"] = df_fra["GCPG"].mean().round(3)

# Each Nation's Each Team's Respective GSPG Difference From Its Country's Average
df_eng["ΔGSPG From Country Avg."] = (df_eng["GSPG"] - df_eng["Country GSPG"]).round(3)
df_ita["ΔGSPG From Country Avg."] = (df_ita["GSPG"] - df_ita["Country GSPG"]).round(3)
df_esp["ΔGSPG From Country Avg."] = (df_esp["GSPG"] - df_esp["Country GSPG"]).round(3)
df_ger["ΔGSPG From Country Avg."] = (df_ger["GSPG"] - df_ger["Country GSPG"]).round(3)
df_por["ΔGSPG From Country Avg."] = (df_por["GSPG"] - df_por["Country GSPG"]).round(3)
df_fra["ΔGSPG From Country Avg."] = (df_fra["GSPG"] - df_fra["Country GSPG"]).round(3)

# Each Nation's Each Team's Respective GCPG Difference From Its Country's Average
df_eng["ΔGCPG From Country Avg."] = (df_eng["GCPG"] - df_eng["Country GCPG"]).round(3)
df_ita["ΔGCPG From Country Avg."] = (df_ita["GCPG"] - df_ita["Country GCPG"]).round(3)
df_esp["ΔGCPG From Country Avg."] = (df_esp["GCPG"] - df_esp["Country GCPG"]).round(3)
df_ger["ΔGCPG From Country Avg."] = (df_ger["GCPG"] - df_ger["Country GCPG"]).round(3)
df_por["ΔGCPG From Country Avg."] = (df_por["GCPG"] - df_por["Country GCPG"]).round(3)
df_fra["ΔGCPG From Country Avg."] = (df_fra["GCPG"] - df_fra["Country GCPG"]).round(3)

# %%
# Converting Some Columns back to now-best Data Types
df_eng[["Matches", "Win", "Draw", "Loss", "GD", "Total Points", "Goals Scored", "Goals Conceded"]] = df_eng[["Matches", "Win", "Draw", "Loss", "GD", "Total Points", "Goals Scored", "Goals Conceded"]].astype(int)
df_ita[["Matches", "Win", "Draw", "Loss", "GD", "Total Points", "Goals Scored", "Goals Conceded"]] = df_ita[["Matches", "Win", "Draw", "Loss", "GD", "Total Points", "Goals Scored", "Goals Conceded"]].astype(int)
df_esp[["Matches", "Win", "Draw", "Loss", "GD", "Total Points", "Goals Scored", "Goals Conceded"]] = df_esp[["Matches", "Win", "Draw", "Loss", "GD", "Total Points", "Goals Scored", "Goals Conceded"]].astype(int)
df_ger[["Matches", "Win", "Draw", "Loss", "GD", "Total Points", "Goals Scored", "Goals Conceded"]] = df_ger[["Matches", "Win", "Draw", "Loss", "GD", "Total Points", "Goals Scored", "Goals Conceded"]].astype(int)
df_por[["Matches", "Win", "Draw", "Loss", "GD", "Total Points", "Goals Scored", "Goals Conceded"]] = df_por[["Matches", "Win", "Draw", "Loss", "GD", "Total Points", "Goals Scored", "Goals Conceded"]].astype(int)
df_fra[["Matches", "Win", "Draw", "Loss", "GD", "Total Points", "Goals Scored", "Goals Conceded"]] = df_fra[["Matches", "Win", "Draw", "Loss", "GD", "Total Points", "Goals Scored", "Goals Conceded"]].astype(int)

# %%
df_eng["Country"] = "England"
df_ita["Country"] = "Italy"
df_esp["Country"] = "Spain"
df_ger["Country"] = "Germany"
df_por["Country"] = "Portugal"
df_fra["Country"] = "France"

# %%
# Standardization | Standardized Scores

from scipy.stats import zscore

df_eng["Standardized WPG in Country"] = zscore(df_eng["WPG"]).round(3)
df_eng["Standardized PPG in Country"] = zscore(df_eng["PPG"]).round(3)
df_eng["Standardized GSPG in Country"] = zscore(df_eng["GSPG"]).round(3)
df_eng["Standardized GCPG in Country"] = zscore(df_eng["GCPG"]).round(3)

df_ita["Standardized WPG in Country"] = zscore(df_ita["WPG"]).round(3)
df_ita["Standardized PPG in Country"] = zscore(df_ita["PPG"]).round(3)
df_ita["Standardized GSPG in Country"] = zscore(df_ita["GSPG"]).round(3)
df_ita["Standardized GCPG in Country"] = zscore(df_ita["GCPG"]).round(3)

df_esp["Standardized WPG in Country"] = zscore(df_esp["WPG"]).round(3)
df_esp["Standardized PPG in Country"] = zscore(df_esp["PPG"]).round(3)
df_esp["Standardized GSPG in Country"] = zscore(df_esp["GSPG"]).round(3)
df_esp["Standardized GCPG in Country"] = zscore(df_esp["GCPG"]).round(3)

df_ger["Standardized WPG in Country"] = zscore(df_ger["WPG"]).round(3)
df_ger["Standardized PPG in Country"] = zscore(df_ger["PPG"]).round(3)
df_ger["Standardized GSPG in Country"] = zscore(df_ger["GSPG"]).round(3)
df_ger["Standardized GCPG in Country"] = zscore(df_ger["GCPG"]).round(3)

df_por["Standardized WPG in Country"] = zscore(df_por["WPG"]).round(3)
df_por["Standardized PPG in Country"] = zscore(df_por["PPG"]).round(3)
df_por["Standardized GSPG in Country"] = zscore(df_por["GSPG"]).round(3)
df_por["Standardized GCPG in Country"] = zscore(df_por["GCPG"]).round(3)

df_fra["Standardized WPG in Country"] = zscore(df_fra["WPG"]).round(3)
df_fra["Standardized PPG in Country"] = zscore(df_fra["PPG"]).round(3)
df_fra["Standardized GSPG in Country"] = zscore(df_fra["GSPG"]).round(3)
df_fra["Standardized GCPG in Country"] = zscore(df_fra["GCPG"]).round(3)

# %%
def formatted_zscore(series):
    """
    Computes z-scores for a series and formats them with '+' for positive values.
    """
    zscores = zscore(series).round(3)  # Compute and round z-scores
    return zscores.apply(lambda x: f"+{x}" if x > 0 else f"{x}")  # Format with '+' if positive

# List of DataFrames
dfs = [df_eng, df_ita, df_esp, df_ger, df_fra, df_por]

# Mapping of original columns to their standardized versions
zscore_columns = {
    "WPG": "Standardized WPG in Country",
    "PPG": "Standardized PPG in Country",
    "GSPG": "Standardized GSPG in Country",
    "GCPG": "Standardized GCPG in Country"
}

# Apply the function to each DataFrame and assign new columns
for df in dfs:
    for orig_col, new_col in zscore_columns.items():
        df[new_col] = formatted_zscore(df[orig_col])

# %%
df_eng["Standardized WPG Rank in Country"] = df_eng["Standardized WPG in Country"].astype(float).rank(method="min", ascending=False).astype(int)
df_eng["Standardized PPG Rank in Country"] = df_eng["Standardized PPG in Country"].astype(float).rank(method="min", ascending=False).astype(int)
df_eng["Standardized GSPG Rank in Country"] = df_eng["Standardized GSPG in Country"].astype(float).rank(method="min", ascending=False).astype(int)
df_eng["Standardized GCPG Rank in Country"] = df_eng["Standardized GCPG in Country"].astype(float).rank(method="min", ascending=True).astype(int)

df_ita["Standardized WPG Rank in Country"] = df_ita["Standardized WPG in Country"].astype(float).rank(method="min", ascending=False).astype(int)
df_ita["Standardized PPG Rank in Country"] = df_ita["Standardized PPG in Country"].astype(float).rank(method="min", ascending=False).astype(int)
df_ita["Standardized GSPG Rank in Country"] = df_ita["Standardized GSPG in Country"].astype(float).rank(method="min", ascending=False).astype(int)
df_ita["Standardized GCPG Rank in Country"] = df_ita["Standardized GCPG in Country"].astype(float).rank(method="min", ascending=True).astype(int)

df_esp["Standardized WPG Rank in Country"] = df_esp["Standardized WPG in Country"].astype(float).rank(method="min", ascending=False).astype(int)
df_esp["Standardized PPG Rank in Country"] = df_esp["Standardized PPG in Country"].astype(float).rank(method="min", ascending=False).astype(int)
df_esp["Standardized GSPG Rank in Country"] = df_esp["Standardized GSPG in Country"].astype(float).rank(method="min", ascending=False).astype(int)
df_esp["Standardized GCPG Rank in Country"] = df_esp["Standardized GCPG in Country"].astype(float).rank(method="min", ascending=True).astype(int)

df_ger["Standardized WPG Rank in Country"] = df_ger["Standardized WPG in Country"].astype(float).rank(method="min", ascending=False).astype(int)
df_ger["Standardized PPG Rank in Country"] = df_ger["Standardized PPG in Country"].astype(float).rank(method="min", ascending=False).astype(int)
df_ger["Standardized GSPG Rank in Country"] = df_ger["Standardized GSPG in Country"].astype(float).rank(method="min", ascending=False).astype(int)
df_ger["Standardized GCPG Rank in Country"] = df_ger["Standardized GCPG in Country"].astype(float).rank(method="min", ascending=True).astype(int)

df_por["Standardized WPG Rank in Country"] = df_por["Standardized WPG in Country"].astype(float).rank(method="min", ascending=False).astype(int)
df_por["Standardized PPG Rank in Country"] = df_por["Standardized PPG in Country"].astype(float).rank(method="min", ascending=False).astype(int)
df_por["Standardized GSPG Rank in Country"] = df_por["Standardized GSPG in Country"].astype(float).rank(method="min", ascending=False).astype(int)
df_por["Standardized GCPG Rank in Country"] = df_por["Standardized GCPG in Country"].astype(float).rank(method="min", ascending=True).astype(int)

df_fra["Standardized WPG Rank in Country"] = df_fra["Standardized WPG in Country"].astype(float).rank(method="min", ascending=False).astype(int)
df_fra["Standardized PPG Rank in Country"] = df_fra["Standardized PPG in Country"].astype(float).rank(method="min", ascending=False).astype(int)
df_fra["Standardized GSPG Rank in Country"] = df_fra["Standardized GSPG in Country"].astype(float).rank(method="min", ascending=False).astype(int)
df_fra["Standardized GCPG Rank in Country"] = df_fra["Standardized GCPG in Country"].astype(float).rank(method="min", ascending=True).astype(int)

# df_eng.head(5)

# %%
# Percentiles

from scipy.stats import percentileofscore

# Function to calculate and format Percentiles
def formatted_percentile(series, value):
    percentile = percentileofscore(series, value, kind="rank")  # Calculate percentile
    return f"{int(round(percentile))}%"  # Round to whole number and add '%'

# Apply to each relevant column - First Main set of Columns

df_eng["Goals Scored Percentile in Country"] = df_eng["Goals Scored"].apply(lambda x: formatted_percentile(df_eng["Goals Scored"], x))
df_eng["Goals Conceded Percentile in Country"] = df_eng["Goals Conceded"].apply(lambda x: formatted_percentile(df_eng["Goals Conceded"], x))
df_eng["Goal Difference Percentile in Country"] = df_eng["GD"].apply(lambda x: formatted_percentile(df_eng["GD"], x))
df_eng["WPG Percentile in Country"] = df_eng["WPG"].apply(lambda x: formatted_percentile(df_eng["WPG"], x))
df_eng["PPG Percentile in Country"] = df_eng["PPG"].apply(lambda x: formatted_percentile(df_eng["PPG"], x))
df_eng["GSPG Percentile in Country"] = df_eng["GSPG"].apply(lambda x: formatted_percentile(df_eng["GSPG"], x))
df_eng["GCPG Percentile in Country"] = df_eng["GCPG"].apply(lambda x: formatted_percentile(df_eng["GCPG"], x))

df_ita["Goals Scored Percentile in Country"] = df_ita["Goals Scored"].apply(lambda x: formatted_percentile(df_ita["Goals Scored"], x))
df_ita["Goals Conceded Percentile in Country"] = df_ita["Goals Conceded"].apply(lambda x: formatted_percentile(df_ita["Goals Conceded"], x))
df_ita["Goal Difference Percentile in Country"] = df_ita["GD"].apply(lambda x: formatted_percentile(df_ita["GD"], x))
df_ita["WPG Percentile in Country"] = df_ita["WPG"].apply(lambda x: formatted_percentile(df_ita["WPG"], x))
df_ita["PPG Percentile in Country"] = df_ita["PPG"].apply(lambda x: formatted_percentile(df_ita["PPG"], x))
df_ita["GSPG Percentile in Country"] = df_ita["GSPG"].apply(lambda x: formatted_percentile(df_ita["GSPG"], x))
df_ita["GCPG Percentile in Country"] = df_ita["GCPG"].apply(lambda x: formatted_percentile(df_ita["GCPG"], x))

df_esp["Goals Scored Percentile in Country"] = df_esp["Goals Scored"].apply(lambda x: formatted_percentile(df_esp["Goals Scored"], x))
df_esp["Goals Conceded Percentile in Country"] = df_esp["Goals Conceded"].apply(lambda x: formatted_percentile(df_esp["Goals Conceded"], x))
df_esp["Goal Difference Percentile in Country"] = df_esp["GD"].apply(lambda x: formatted_percentile(df_esp["GD"], x))
df_esp["WPG Percentile in Country"] = df_esp["WPG"].apply(lambda x: formatted_percentile(df_esp["WPG"], x))
df_esp["PPG Percentile in Country"] = df_esp["PPG"].apply(lambda x: formatted_percentile(df_esp["PPG"], x))
df_esp["GSPG Percentile in Country"] = df_esp["GSPG"].apply(lambda x: formatted_percentile(df_esp["GSPG"], x))
df_esp["GCPG Percentile in Country"] = df_esp["GCPG"].apply(lambda x: formatted_percentile(df_esp["GCPG"], x))

df_ger["Goals Scored Percentile in Country"] = df_ger["Goals Scored"].apply(lambda x: formatted_percentile(df_ger["Goals Scored"], x))
df_ger["Goals Conceded Percentile in Country"] = df_ger["Goals Conceded"].apply(lambda x: formatted_percentile(df_ger["Goals Conceded"], x))
df_ger["Goal Difference Percentile in Country"] = df_ger["GD"].apply(lambda x: formatted_percentile(df_ger["GD"], x))
df_ger["WPG Percentile in Country"] = df_ger["WPG"].apply(lambda x: formatted_percentile(df_ger["WPG"], x))
df_ger["PPG Percentile in Country"] = df_ger["PPG"].apply(lambda x: formatted_percentile(df_ger["PPG"], x))
df_ger["GSPG Percentile in Country"] = df_ger["GSPG"].apply(lambda x: formatted_percentile(df_ger["GSPG"], x))
df_ger["GCPG Percentile in Country"] = df_ger["GCPG"].apply(lambda x: formatted_percentile(df_ger["GCPG"], x))

df_por["Goals Scored Percentile in Country"] = df_por["Goals Scored"].apply(lambda x: formatted_percentile(df_por["Goals Scored"], x))
df_por["Goals Conceded Percentile in Country"] = df_por["Goals Conceded"].apply(lambda x: formatted_percentile(df_por["Goals Conceded"], x))
df_por["Goal Difference Percentile in Country"] = df_por["GD"].apply(lambda x: formatted_percentile(df_por["GD"], x))
df_por["WPG Percentile in Country"] = df_por["WPG"].apply(lambda x: formatted_percentile(df_por["WPG"], x))
df_por["PPG Percentile in Country"] = df_por["PPG"].apply(lambda x: formatted_percentile(df_por["PPG"], x))
df_por["GSPG Percentile in Country"] = df_por["GSPG"].apply(lambda x: formatted_percentile(df_por["GSPG"], x))
df_por["GCPG Percentile in Country"] = df_por["GCPG"].apply(lambda x: formatted_percentile(df_por["GCPG"], x))

df_fra["Goals Scored Percentile in Country"] = df_fra["Goals Scored"].apply(lambda x: formatted_percentile(df_fra["Goals Scored"], x))
df_fra["Goals Conceded Percentile in Country"] = df_fra["Goals Conceded"].apply(lambda x: formatted_percentile(df_fra["Goals Conceded"], x))
df_fra["Goal Difference Percentile in Country"] = df_fra["GD"].apply(lambda x: formatted_percentile(df_fra["GD"], x))
df_fra["WPG Percentile in Country"] = df_fra["WPG"].apply(lambda x: formatted_percentile(df_fra["WPG"], x))
df_fra["PPG Percentile in Country"] = df_fra["PPG"].apply(lambda x: formatted_percentile(df_fra["PPG"], x))
df_fra["GSPG Percentile in Country"] = df_fra["GSPG"].apply(lambda x: formatted_percentile(df_fra["GSPG"], x))
df_fra["GCPG Percentile in Country"] = df_fra["GCPG"].apply(lambda x: formatted_percentile(df_fra["GCPG"], x))

# To the other Main Set of Columns

# df_eng["Standardized WPG Percentile in Country"] = df_eng["Standardized WPG in Country"].apply(lambda x: formatted_percentile(df_eng["Standardized WPG in Country"], x))
# df_eng["Standardized PPG Percentile in Country"] = df_eng["Standardized PPG in Country"].apply(lambda x: formatted_percentile(df_eng["Standardized PPG in Country"], x))
# df_eng["Standardized GSPG Percentile in Country"] = df_eng["Standardized GSPG in Country"].apply(lambda x: formatted_percentile(df_eng["Standardized GSPG in Country"], x))
# df_eng["Standardized GCPG Percentile in Country"] = df_eng["Standardized GCPG in Country"].apply(lambda x: formatted_percentile(df_eng["Standardized GCPG in Country"], x))

# df_ita["Standardized WPG Percentile in Country"] = df_ita["Standardized WPG in Country"].apply(lambda x: formatted_percentile(df_ita["Standardized WPG in Country"], x))
# df_ita["Standardized PPG Percentile in Country"] = df_ita["Standardized PPG in Country"].apply(lambda x: formatted_percentile(df_ita["Standardized PPG in Country"], x))
# df_ita["Standardized GSPG Percentile in Country"] = df_ita["Standardized GSPG in Country"].apply(lambda x: formatted_percentile(df_ita["Standardized GSPG in Country"], x))
# df_ita["Standardized GCPG Percentile in Country"] = df_ita["Standardized GCPG in Country"].apply(lambda x: formatted_percentile(df_ita["Standardized GCPG in Country"], x))

# df_esp["Standardized WPG Percentile in Country"] = df_esp["Standardized WPG in Country"].apply(lambda x: formatted_percentile(df_esp["Standardized WPG in Country"], x))
# df_esp["Standardized PPG Percentile in Country"] = df_esp["Standardized PPG in Country"].apply(lambda x: formatted_percentile(df_esp["Standardized PPG in Country"], x))
# df_esp["Standardized GSPG Percentile in Country"] = df_esp["Standardized GSPG in Country"].apply(lambda x: formatted_percentile(df_esp["Standardized GSPG in Country"], x))
# df_esp["Standardized GCPG Percentile in Country"] = df_esp["Standardized GCPG in Country"].apply(lambda x: formatted_percentile(df_esp["Standardized GCPG in Country"], x))

# df_ger["Standardized WPG Percentile in Country"] = df_ger["Standardized WPG in Country"].apply(lambda x: formatted_percentile(df_ger["Standardized WPG in Country"], x))
# df_ger["Standardized PPG Percentile in Country"] = df_ger["Standardized PPG in Country"].apply(lambda x: formatted_percentile(df_ger["Standardized PPG in Country"], x))
# df_ger["Standardized GSPG Percentile in Country"] = df_ger["Standardized GSPG in Country"].apply(lambda x: formatted_percentile(df_ger["Standardized GSPG in Country"], x))
# df_ger["Standardized GCPG Percentile in Country"] = df_ger["Standardized GCPG in Country"].apply(lambda x: formatted_percentile(df_ger["Standardized GCPG in Country"], x))

# df_por["Standardized WPG Percentile in Country"] = df_por["Standardized WPG in Country"].apply(lambda x: formatted_percentile(df_por["Standardized WPG in Country"], x))
# df_por["Standardized PPG Percentile in Country"] = df_por["Standardized PPG in Country"].apply(lambda x: formatted_percentile(df_por["Standardized PPG in Country"], x))
# df_por["Standardized GSPG Percentile in Country"] = df_por["Standardized GSPG in Country"].apply(lambda x: formatted_percentile(df_por["Standardized GSPG in Country"], x))
# df_por["Standardized GCPG Percentile in Country"] = df_por["Standardized GCPG in Country"].apply(lambda x: formatted_percentile(df_por["Standardized GCPG in Country"], x))

# df_fra["Standardized WPG Percentile in Country"] = df_fra["Standardized WPG in Country"].apply(lambda x: formatted_percentile(df_fra["Standardized WPG in Country"], x))
# df_fra["Standardized PPG Percentile in Country"] = df_fra["Standardized PPG in Country"].apply(lambda x: formatted_percentile(df_fra["Standardized PPG in Country"], x))
# df_fra["Standardized GSPG Percentile in Country"] = df_fra["Standardized GSPG in Country"].apply(lambda x: formatted_percentile(df_fra["Standardized GSPG in Country"], x))
# df_fra["Standardized GCPG Percentile in Country"] = df_fra["Standardized GCPG in Country"].apply(lambda x: formatted_percentile(df_fra["Standardized GCPG in Country"], x))

# %%
df = pd.concat([df_eng, df_ita, df_esp, df_ger, df_por, df_fra])

# Initially, I Grouped by this Operation Raw, and Saw a Team with a very Small Sample of Matches Played but a lot of
# PPG; so, I decided to, firstly, Filter out for Teams that had Played a Minimum of 1500 Matches in the First Division

df = df[df["Matches"] > 1500].sort_values(by="PPG", ascending=False)

# %%
# df.head(10)

# %%
df["GS Percentile in Country Numeric"] = df["Goals Scored Percentile in Country"].str.strip("%").astype(float)
df["GC Percentile in Country Numeric"] = df["Goals Conceded Percentile in Country"].str.strip("%").astype(float)
df["GD Percentile in Country Numeric"] = df["Goal Difference Percentile in Country"].str.strip("%").astype(float)
df["WPG Percentile in Country Numeric"] = df["WPG Percentile in Country"].str.strip("%").astype(float)
df["PPG Percentile in Country Numeric"] = df["PPG Percentile in Country"].str.strip("%").astype(float)
df["GSPG Percentile in Country Numeric"] = df["GSPG Percentile in Country"].str.strip("%").astype(float)
df["GCPG Percentile in Country Numeric"] = df["GCPG Percentile in Country"].str.strip("%").astype(float)

# %%
df.loc[:, df.columns.str.contains("Rank")] = df.loc[:, df.columns.str.contains("Rank")].astype(str) # Selects only those Columns which contain "Rank" in their respective Names and Converts their Values into String format
df_num = df.select_dtypes(include = np.number)

# df_num.corr()

# %%
# Standardized Measures and Percentiles for Final, Combined Table

df["Standardized WPG - Overall"] = zscore(df["WPG"]).round(3)
df["Standardized PPG - Overall"] = zscore(df["PPG"]).round(3)
df["Standardized GSPG - Overall"] = zscore(df["GSPG"]).round(3)
df["Standardized GCPG - Overall"] = zscore(df["GCPG"]).round(3)

# Function to calculate and format Percentiles
def formatted_percentile(series, value):
    percentile = percentileofscore(series, value, kind="rank")  # Calculate percentile
    return f"{int(round(percentile))}%"  # Round to whole number and add '%'

# Apply to each relevant column - First Main set of Columns

df["Goals Scored Percentile - Overall"] = df["Goals Scored"].apply(lambda x: formatted_percentile(df["Goals Scored"], x))
df["Goals Conceded Percentile - Overall"] = df["Goals Conceded"].apply(lambda x: formatted_percentile(df["Goals Conceded"], x))
df["Goal Difference Percentile - Overall"] = df["GD"].apply(lambda x: formatted_percentile(df["GD"], x))
df["WPG Percentile - Overall"] = df["WPG"].apply(lambda x: formatted_percentile(df["WPG"], x))
df["PPG Percentile - Overall"] = df["PPG"].apply(lambda x: formatted_percentile(df["PPG"], x))
df["GSPG Percentile - Overall"] = df["GSPG"].apply(lambda x: formatted_percentile(df["GSPG"], x))
df["GCPG Percentile - Overall"] = df["GCPG"].apply(lambda x: formatted_percentile(df["GCPG"], x))

# %%
def formatted_zscore(series):
    """
    Computes z-scores for a series and formats them with '+' for positive values.
    """
    zscores = zscore(series).round(3)  # Compute and round z-scores
    return zscores.apply(lambda x: f"+{x}" if x > 0 else f"{x}")  # Format with '+' if positive

# List of DataFrames
dfs = df

# Mapping of original columns to their standardized versions
zscore_columns = {
    "WPG": "Standardized WPG - Overall",
    "PPG": "Standardized PPG - Overall",
    "GSPG": "Standardized GSPG - Overall",
    "GCPG": "Standardized GCPG - Overall"
}

# Apply to the DataFrame
for orig_col, new_col in zscore_columns.items():
    df[new_col] = formatted_zscore(df[orig_col])

# %%
df.head(8)
# Out:
#   All-Time Domestic Position            Team  Matches   Win  Draw  Loss  \
# 0                          1      SL Benfica     2159  1485   417   257
# 1                          2        FC Porto     2160  1486   407   267
# 2                          3     Sporting CP     2160  1305   484   371
# 0                          1  Bayern München     2036  1231   436   369
# 0                          1     Real Madrid     3056  1838   613   605
# 1                          2    FC Barcelona     3055  1778   616   661
# 0                          1        Juventus     3147  1728   857   562
# 1                          2           Inter     3186  1616   867   703
#
#        GS:GC    GD  Total Points  Goals Scored  Goals Conceded    PPG    WPG  \
# 0  4869:1635  3234          4872          4869            1635  2.257  0.688
# 1  4513:1534  2979          4859          4513            1534  2.250  0.688
# 2  4111:1837  2274          4399          4111            1837  2.037  0.604
# ...

# %%
# df.groupby("Country")[["GSPG", "GCPG", "ΔGCPG From Country Avg.", "ΔGSPG From Country Avg."]].mean().round(3)

# %%
# f1 = df[df["Matches"] > 3000]

# for i, team in enumerate(f1["Team"]):
#        print(f"**{team}** have Played more than 3000 Top-Flight Games.")

# %%
# "f1["Country"].value_counts()": This counts the occurrences of each unique country in the Country column of the filtered DataFrame "f1"
# ".items()": Converts the result into key-value pairs (country and its count) for iteration.
# ".value_counts()": Gives you the count of each country.
# "count": Dynamically represents the value for each country.

# for i, count in f1["Country"].value_counts().items():
#    print(f"{count} {i} Teams have Played more than 3000 First Division Games.")

# %%
topfive_bestdefpg = df.groupby("Country").apply(lambda x: x.nsmallest(5, ["GCPG"]))
topfive
# Out:
#            All-Time Domestic Position                 Team  Matches   Win  \
# Country
# England  3                          4    Manchester United     3996  1915
#          0                          1         Liverpool FC     4353  2080
#          1                          2           Arsenal FC     4352  2009
#          6                          7    Tottenham Hotspur     3612  1514
#          7                          8           Chelsea FC     3616  1489
# France   6                          7  Paris Saint-Germain     1928   947
#          1                          2            AS Monaco     2430  1095
#          0                          1  Olympique Marseille     2675  1199
#          4                          5   Olympique Lyonnais     2459  1058
#          2                          3   Girondins Bordeaux     2544  1075
# Germany  0                          1       Bayern München     2036  1231
# ...

# %% [markdown]
# ### Also, plan to Standardize Measures based on European whole data and Rank teams absed on European whole data too, after Combining all DataFrames

# %%
# Apply the "+" sign before values greater than 0.000
## df['Country GSPG'] = df['Country GSPG'].apply(lambda x: f"+{x}" if x > 0.000 else str(x))

# %%
#for name, country, ppg in zip(df["Team"], df["Country"], df["PPG"]):
#   print(f"{name} of {country} has a Total Average of {ppg} Point Earned per Game Across their History.")

# %%
# Calculate the correlations of each metric with 'PPG'
correlations = df.corr(numeric_only=True)["PPG"]

# Drop 'PPG' as we are not interested in its correlation with itself
correlations = correlations.drop('PPG')

# Select only the columns of interest for normalization
columns_of_interest = ["WPG", "DPG", "LPG", "GSPG", "GCPG"]
correlations_selected = correlations[columns_of_interest]

# Normalize the selected correlations to make them sum to 1
normalized_weights = correlations_selected / correlations_selected.sum()

# Final normalized weights for the five metrics
norw_weights = normalized_weights

print(norw_weights)
# Out:
# WPG    -2.833747
# DPG     1.250133
# LPG     2.765866
# GSPG   -2.508626
# GCPG    2.326374
# Name: PPG, dtype: float64

# %%
# Clean any non-numeric columns explicitly
df_eq = df.apply(pd.to_numeric, errors='coerce')

# Calculate the correlations of each metric with 'PPG'
correlations = df_eq.corr(numeric_only=True)["PPG"]

# Drop 'PPG' as we are not interested in its correlation with itself
correlations = correlations.drop('PPG')

# Select only the columns of interest for normalization
columns_of_interest = ["WPG", "DPG", "LPG", "GSPG", "GCPG"]
correlations_selected = correlations[columns_of_interest]

# Normalize the selected correlations to make them sum to 1
normalized_weights = correlations_selected / correlations_selected.sum()

# Final normalized weights for the five metrics
norw_weights = normalized_weights

print("\nNormalized Weights:")
print(norw_weights)

# Function to calculate composite PPG based on weighted sum of normalized metrics
def calculate_composite_ppg():
    print("Enter the values for the following metrics:")

    # Get user input for each metric (WPG, DPG, LPG, GSPG, GCPG)
    WPG = float(input("Enter Wins per Game (WPG): "))
    DPG = float(input("Enter Draws per Game (DPG): "))
    LPG = float(input("Enter Losses per Game (LPG): "))
    GSPG = float(input("Enter Goals Scored per Game (GSPG): "))
    GCPG = float(input("Enter Goals Conceded per Game (GCPG): "))

    # Normalize the input values based on dataset's Min-Max (assuming dataset ranges)
    min_values = df_eq[columns_of_interest].min()  # Minimum values for each relevant column
    max_values = df_eq[columns_of_interest].max()  # Maximum values for each relevant column

    input_data = np.array([WPG, DPG, LPG, GSPG, GCPG])
    input_data_normalized = (input_data - min_values) / (max_values - min_values)

    # Calculate the weighted sum (composite PPG)
    composite_ppg = np.dot(input_data_normalized, norw_weights)

    # Print the result
    print(f"\nComposite PPG Estimate: {composite_ppg:.3f}")

# Call the function
#calculate_composite_ppg()
# Out:
# Normalized Weights:
# WPG    -2.827191
# DPG     1.250135
# LPG     2.759411
# GSPG   -2.503355
# GCPG    2.321000
# Name: PPG, dtype: float64

# %%
# ! CORRECT: Using Linear Regression to Predict Actual PPG | Note for Future

from sklearn.linear_model import LinearRegression

# Prepare the feature columns
features = ["WPG", "DPG", "LPG", "GSPG", "GCPG"]
X = df[features]  # feature matrix
y = (df["Total Points"] / df["Matches"]) * 38     # target variable

# Fit a linear regression model
model = LinearRegression()
model.fit(X, y)

# Get the coefficients (weights)
model_weights = model.coef_
intercept = model.intercept_

# Updating the Function to use the Regression Model

def calculate_composite_pts_regression():
    print("Enter the values for the following metrics:")

    # Get user input for each metric (WPG, DPG, LPG, GSPG, GCPG)
    WPG = float(input("Enter Average Wins per Match: "))
    DPG = float(input("Enter Average Draws per Match: "))
    LPG = float(input("Enter Average Losses per Match: "))
    GSPG = float(input("Enter Average Goals Scored per Match: "))
    GCPG = float(input("Enter Average Goals Conceded per Match: "))
    
    # Create input data based on user input
    input_data = np.array([WPG, DPG, LPG, GSPG, GCPG]).reshape(1, -1)

    # Use the trained regression model to predict the actual PPG
    composite_pts = model.predict(input_data)[0]

    # Print the result
    print(f"\nPredicted Actual PPG: {composite_pts:.1f}")

# Call the updated function
#calculate_composite_pts_regression()

# %%
# Print the equation
def print_regression_equation():
    equation = f"Predicted Total Points = {intercept:.2f} "
    for i, feature in enumerate(features):
        equation += f"+ ({model_weights[i]:.2f} * {feature}) "
    print(f"Regression Equation: {equation.strip()}")

print_regression_equation()
# Out:
# Regression Equation: Predicted Total Points = 50.60 + (63.86 * WPG) + (-13.87 * DPG) + (-50.14 * LPG) + (-0.09 * GSPG) + (0.07 * GCPG)

# %%
def calculate_total_points():
    print("Enter the values for the following metrics:")

    # Get user input for each metric (WPG, DPG, LPG, GSPG, GCPG)
    WPG = float(input("Enter Average Wins per Match (WPG): "))
    DPG = float(input("Enter Average Draws per Match (DPG): "))
    LPG = float(input("Enter Average Losses per Match (LPG): "))
    GSPG = float(input("Enter Average Goals Scored per Match (GSPG): "))
    GCPG = float(input("Enter Average Goals Conceded per Match (GCPG): "))
    
    # Regression equation parameters
    intercept = 46.02
    coef_wpg = 67.96
    coef_dpg = -9.23
    coef_lpg = -45.37
    coef_gspg = 0.07
    coef_gcpg = -0.03

    # Calculate predicted total points using the regression equation
    predicted_total_points = (intercept 
                              + coef_wpg * WPG 
                              + coef_dpg * DPG 
                              + coef_lpg * LPG 
                              + coef_gspg * GSPG 
                              + coef_gcpg * GCPG)
    
    # Print the result
    print(f"\nPredicted Total Points: {predicted_total_points:.1f}")

# Call the function to get user input and calculate the result
#calculate_total_points()

# %%
df[df["Team"] == "Liverpool FC"]
# Out:
#   All-Time Position          Team  Matches   Win  Draw  Loss      GS:GC    GD  \
# 0                 1  Liverpool FC     4353  2080  1078  1195  7345:5218  2127
#
#    Total Points  Goals Scored  Goals Conceded    PPG    WPG    DPG    LPG  \
# 0          7318          7345            5218  1.681  0.478  0.248  0.275
#
#     GSPG   GCPG  Country GSPG  Country GCPG  ΔGSPG From Country Avg.  \
# 0  1.687  1.199         1.363         1.623                    0.324
#
#    ΔGCPG From Country Avg.  Country
# 0                   -0.424  England

# %%
df.corr(numeric_only=True).loc["PPG", ["Win", "Draw", "Loss", "Goals Scored", "Goals Conceded"]]
# Out:
# Win               0.668883
# Draw              0.106755
# Loss             -0.403752
# Goals Scored      0.548609
# Goals Conceded   -0.149669
# Name: PPG, dtype: float64

# %%
# The Highest number of Matches a Team has played in the First Division is 4729.
# So, let's Simulate each Team's Performance as if it had Played the Maximum Amount of Games possible.

df["Expected Max Points"] = (df["PPG"]*4729).astype(int)

# Now, let's go and look at the Top Teams Based on that!

df.sort_values(by="Expected Max Points", ascending=False, inplace=True)
df.reset_index(inplace=True)
df.drop(columns=["index"], inplace=True)

df.head(10)
# Out:
#   All-Time Position                 Team  Matches   Win  Draw  Loss  \
# 0                 1           SL Benfica     2158  1484   417   257
# 1                 2             FC Porto     2159  1485   407   267
# 2                 3          Sporting CP     2159  1304   484   371
# 3                 1       Bayern München     2035  1231   435   369
# 4                 1          Real Madrid     3055  1837   613   605
# 5                 2         FC Barcelona     3054  1777   616   661
# 6                 1             Juventus     3146  1728   857   561
# 7                 2                Inter     3185  1615   867   703
# 8                 3             AC Milan     3122  1519   909   694
# 9                 7  Paris Saint-Germain     1928   947   496   485
#
#        GS:GC    GD  Total Points  Goals Scored  Goals Conceded    PPG    WPG  \
# 0  4866:1633  3233          4869          4866            1633  2.256  0.688
# ...

# %%
df[['Team', 'Country', 'Matches', 'Win', 'Draw', 'Loss', 'GSPG', 'GCPG', 'ΔGSPG From Country Avg.', 'ΔGCPG From Country Avg.',
            'WPG', 'PPG', 'Expected Max Points']].head(12)
# Out:
#                    Team   Country  Matches   Win  Draw  Loss   GSPG   GCPG  \
# 0            SL Benfica  Portugal     2158  1484   417   257  2.255  0.757
# 1              FC Porto  Portugal     2159  1485   407   267  2.089  0.711
# 2           Sporting CP  Portugal     2159  1304   484   371  1.903  0.850
# 3        Bayern München   Germany     2035  1231   435   369  2.255  1.091
# 4           Real Madrid     Spain     3055  1837   613   605  2.141  1.114
# 5          FC Barcelona     Spain     3054  1777   616   661  2.144  1.107
# 6              Juventus     Italy     3146  1728   857   561  1.744  0.941
# 7                 Inter     Italy     3185  1615   867   703  1.710  1.025
# 8              AC Milan     Italy     3122  1519   909   694  1.643  1.032
# 9   Paris Saint-Germain    France     1928   947   496   485  1.645  1.063
# 10      Atlético Madrid     Spain     2907  1414   670   823  1.725  1.221
# ...

# %%
plt.figure(figsize=(9,8))

sns.heatmap(df.corr(numeric_only=True), annot=True, fmt=".2f", cmap='coolwarm', linewidths=1.0, square=True)
plt.show()

# %%
# Step 2: Reset index for easier plotting
topfive = topfive.reset_index(drop=True)

# Step 3: Assigning Unique colors to each Country
countries = topfive["Country"].unique()
color_map = sns.color_palette("tab10", len(countries))  # Unique color for each country
country_colors = {country: color_map[i] for i, country in enumerate(countries)}

# Step 4: Creating the Bar plot
plt.figure(figsize=(14, 8))

# Initialize bar positions
bar_position = 0
bar_width = 1.0
country_positions = []  # Store midpoints of each country's bars for labeling

# Looping through each Country to plot its Teams
for country in countries:
    country_data = topfive[topfive["Country"] == country]
    
    # Plot the bars
    bars = plt.bar(
        x=range(bar_position, bar_position + len(country_data)),  # Unique positions for bars
        height=country_data["PPG"], 
        color=country_colors[country], 
        label=country
    )
    
    # Add team names and PPG values inside the bars, vertically oriented
    for bar, (team_name, ppg_value) in zip(bars, zip(country_data["Team"], country_data["PPG"])):
        plt.text(
            bar.get_x() + bar.get_width() / 2,  # Center the text horizontally
            bar.get_height() / 2,  # Position vertically at half the bar height
            f"{team_name} ({ppg_value:.3f})",  # Add team name and PPG value
            ha='center', 
            va='center', 
            rotation=90,  # Rotate text vertically
            fontsize=10, 
            color='white'  # Text color for visibility
        )
    
    # Store the midpoint of the bars for this country
    midpoint = bar_position + len(country_data) / 2 - 0.5
    country_positions.append((midpoint, country))
    
    # Update the bar position
    bar_position += len(country_data)

# Step 5: Adding Country Names to the gaps
for position, country in country_positions:
    plt.text(
        x=position, 
        y=-0.02,  # Below the bars
        s=country, 
        ha='center', 
        va='top', 
        fontsize=13, 
        fontweight='bold', 
        color='black'
    )

# Step 6: Add a legend
plt.legend(title="Country", fontsize=10, loc='upper right')

plt.title("Top Five Teams with Highest Average PPG by Country")
plt.xlabel("PPG and by Country")
plt.ylabel("Average PPG")

plt.show()

# %%
plt.scatter(x=df["Matches"], y=df["PPG"])
plt.xlabel("Total Matches Played")
plt.ylabel("Average PPG")

plt.show()

# %%
eng_avg_gs = df[df["Country"] == "England"]["Goals Scored"].mean().round(2)
ita_avg_gs = df[df["Country"] == "Italy"]["Goals Scored"].mean().round(2)
esp_avg_gs = df[df["Country"] == "Spain"]["Goals Scored"].mean().round(2)
ger_avg_gs = df[df["Country"] == "Germany"]["Goals Scored"].mean().round(2)
por_avg_gs = df[df["Country"] == "Portugal"]["Goals Scored"].mean().round(2)
fra_avg_gs = df[df["Country"] == "France"]["Goals Scored"].mean().round(2)

# print(eng_avg_gs)
# print("")
# print(ita_avg_gs)
# print("")
# print(esp_avg_gs)
# print("")
# print(ger_avg_gs)
# print("")
# print(por_avg_gs)
# print("")
# print(fra_avg_gs)
# print("")

# avg_gs = df["Goals Scored"].mean().round(2)

# %%
eng_dist_gs = np.arange(30, df_eng['Goals Scored'].max()+1)

# %%
from scipy.stats import poisson

poisson_gs = poisson.pmf(eng_dist_gs, eng_avg_gs)

# Plot histogram for Home Goals
plt.hist(df[df["Country"] == "England"]['Goals Scored'], bins = 10, 
         alpha=0.7, label='Actual Total Goals Scored by English Teams', color='blue', density=True)

# Plot Poisson distribution
plt.plot(eng_dist_gs, poisson_gs, color='red', label='Poisson (Goals Scored)', linewidth=2)
plt.grid(alpha=0.4)
plt.show()

# poisson.pmf(*range of distribution - create with "np.arange(0,...)"*, *average of that measurement*)
# bins = range(df[df["Country"] == "England"]["Goals Scored"].max() + 2)

# %%
# Calculate average wins for English teams
eng_avg_wins = df[df["Country"] == "England"]["Win"].mean().round(2)

# X-axis range based on max wins
eng_wins_xrange = np.arange(0, df[df["Country"] == "England"]["Win"].max() + 1)

# Poisson PMF
poisson_gs = poisson.pmf(eng_wins_xrange, eng_avg_wins)

# Plotting
plt.figure(figsize=(8, 6))

# 1️⃣ Histogram for Wins
plt.hist(df[df["Country"] == "England"]['Win'], bins=range(0, df['Win'].max() + 2), 
         alpha=0.7, label='Actual Total Wins by English Teams', color='blue', density=True)

# 2️⃣ Poisson Curve (using correct x-range)
plt.plot(eng_wins_xrange, poisson_gs, color='red', label='Poisson (Wins)', linewidth=2)

# Labels & Grid
plt.title('Poisson Distribution - Wins by English Teams')
plt.xlabel('Number of Wins')
plt.ylabel('Probability Density')
plt.grid(alpha=0.4)
plt.legend()
plt.show()

# %% [markdown]
# # Making a Win Probability Model
#
# ### Using Linear Regression, Measuring a Team's Probability of Winning based on Goals Scored, Goals Conceded, and Matches Played so far
# ### Also Measuring each Variable's Quantified Correlation with the Outcome of "Win"

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as MSE
from sklearn.preprocessing import StandardScaler as SS

# %%
# Defining the Features (X) and Target/Outcome variable (y) for Multiple Linear Regression
X = df[["WPG", "DPG", "LPG"]]
y = df["PPG"]

# Normalizing the Features & the Target variable
scaler = SS()

X_norm = scaler.fit_transform(X)
y_norm = scaler.fit_transform(y.values.reshape(-1, 1))

# Splitting the Data
X_train, X_test, y_train, y_test = train_test_split(X_norm, y_norm, test_size = 0.2, random_state=42)

# Creating and Fitting the Multiple Linear Regression Model
model = LinearRegression()
model.fit(X_train, y_train)

# Coefficients and Y-Intercept
intercept = model.intercept_
coefficients = model.coef_

print(intercept)
print("")

coef_df = pd.DataFrame({"Feature": ["Wins PG", "Draws PG", "Losses PG"], "Coefficient": coefficients.flatten()})
print(coef_df) # Coefficients taken from the "coefficients" DataFrame created
# Out:
# [0.00016718]
#
#      Feature  Coefficient
# 0    Wins PG     0.599700
# 1   Draws PG    -0.039994
# 2  Losses PG    -0.396066

# %%
# Making Predictions on the Test Set
y_pred = model.predict(X_test)

# %%
# Calculating Residuals (Errors)
# residuals = y_test - y_pred

from sklearn.metrics import r2_score, mean_squared_error

# Predicting on Test Data
y_pred = model.predict(X_test)

# Ensure y_test and y_pred are 1D
y_test = y_test.ravel()
y_pred = y_pred.ravel()

# Calculating Residuals (Errors)
residuals = y_test - y_pred

# Model Evaluation
from sklearn.metrics import r2_score, mean_squared_error

print("R² Score:", r2_score(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
# Out:
# R² Score: 0.9998539265094326
# MSE: 0.00019474294214852963
